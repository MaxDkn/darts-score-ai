# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxDkn/darts-score-ai/blob/dev/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import platform
import distro

# %%
os = platform.system()
print(f"{platform.system()} {platform.release()}")
print(f"Architecture : {platform.machine()}")
if os == 'Linux':
  print(f"Distribution {os} : {distro.name()} {distro.version()}")
# Out:
# Linux 6.1.123+
# Architecture : x86_64
# Distribution Linux : Ubuntu 22.04

# %% [markdown]
# #  Download bender for Linux OS

# %%
# !wget https://mirror.clarkson.edu/blender/release/Blender4.4/blender-4.4.3-linux-x64.tar.xz
# !tar -xf blender-4.4.3-linux-x64.tar.xz
# Out:
# --2025-06-28 13:50:45--  https://mirror.clarkson.edu/blender/release/Blender4.4/blender-4.4.3-linux-x64.tar.xz
# Resolving mirror.clarkson.edu (mirror.clarkson.edu)... 128.153.145.19, 2605:6480:c051:100::1
# Connecting to mirror.clarkson.edu (mirror.clarkson.edu)|128.153.145.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 363316148 (346M) [application/octet-stream]
# Saving to: ‘blender-4.4.3-linux-x64.tar.xz’
#
# blender-4.4.3-linux 100%[===================>] 346.48M  8.18MB/s    in 42s
#
# 2025-06-28 13:51:28 (8.16 MB/s) - ‘blender-4.4.3-linux-x64.tar.xz’ saved [363316148/363316148]

# %%
# !blender-4.4.3-linux-x64/blender --version
# Out:
# Blender 4.4.3
# 	build date: 2025-04-29
# 	build time: 15:12:13
# 	build commit date: 2025-04-29
# 	build commit time: 14:09
# 	build hash: 802179c51ccc
# 	build branch: blender-v4.4-release
# 	build platform: Linux
# 	build type: Release
# 	build c flags:  -Wall -Werror=implicit-function-declaration -Wstrict-prototypes -Werror=return-type -Werror=vla -Wmissing-prototypes -Wno-char-subscripts -Wno-unknown-pragmas -Wpointer-arith -Wunused-parameter -Wwrite-strings -Wlogical-op -Wundef -Winit-self -Wmissing-include-dirs -Wno-div-by-zero -Wtype-limits -Wformat-signedness -Wrestrict -Wno-stringop-overread -Wno-stringop-overflow -Wnonnull -Wabsolute-value -Wuninitialized -Wredundant-decls -Wshadow -Wimplicit-fallthrough=5 -Wno-error=unused-but-set-variable  -march=x86-64-v2 -std=gnu11 -pipe -fPIC -funsigned-char -fno-strict-aliasing -ffp-contract=off
# ...
